# %%
import pandas as pd

df = pd.DataFrame({
    'age': [25, 30, 35, 40, 45],
    'experience_years': [2, 5, 8, 12, 20],
    'salary': [30000, 45000, 60000, 80000, 100000],
    'performance_score': [3.5, 4.0, 4.3, 4.6, 4.8],
    'absent_days': [10, 7, 5, 3, 1]
})

# %%
corr = df.corr()
corr
# Out:
#                         age  experience_years    salary  performance_score  \
# age                1.000000          0.973259  0.997155           0.986602
# experience_years   0.973259          1.000000  0.985322           0.929515
# salary             0.997155          0.985322  1.000000           0.973255
# performance_score  0.986602          0.929515  0.973255           1.000000
# absent_days       -0.995893         -0.956967 -0.987901          -0.996507
#
#                    absent_days
# age                  -0.995893
# experience_years     -0.956967
# salary               -0.987901
# performance_score    -0.996507
# absent_days           1.000000

# %%
df[['performance_score','experience_years','absent_days']].corr()
# Out:
#                    performance_score  experience_years  absent_days
# performance_score           1.000000          0.929515    -0.996507
# experience_years            0.929515          1.000000    -0.956967
# absent_days                -0.996507         -0.956967     1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as pyplot

sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
plt.title('Employee Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       2 import matplotlib.pyplot as pyplot
#       4 sns.heatmap(df.corr(),annot=True,cmap="coolwarm")
# ----> 5 plt.title('Employee Correlation Heatmap')
#       6 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from sklearn.linear_model import LinearRegression

X = df[['experience_years']]
y = df['salary']

model = LinearRegression()
model.fit(X,y)

print('Salary increae per year',model.coef_[0])
print('Base salary',model.intercept_)
# Out:
# Salary increae per year 3913.934426229508
# Base salary 26209.016393442624
