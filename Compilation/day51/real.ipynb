# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pymongo import MongoClient
from pymongo.errors import PyMongoError

# %%
try:
    client = MongoClient("mongodb://localhost:27017/")
    print("Connected to MongoDB server")
except pymongo.errors.ConnectionFailure as e:
    print(f"Could not connect to MongoDB: {e}")
    exit()


try:
    db = client["practice"]
    print("Connected to database:", db.name)
except Exception as e:
    print(f"Database error: {e}")
    exit()
# Out:
# Connected to MongoDB server
# Connected to database: practice

# %%
print("Collections:", db.list_collection_names())
# Out:
# Collections: ['real_state', 'movies', 'employees']

# %%
real_state = db["real_state"]

# %%
list_of_data = real_state.find()
list_data = pd.DataFrame(list_of_data)
list_data
# Out:
#                          _id property_id                            address  \
# 0   696bc5c5d1b57fd7f4c1b491        P001     123 Maple Ave, Springfield, IL
# 1   696bc5c5d1b57fd7f4c1b492        P002        456 Oak St, Springfield, IL
# 2   696bc5c5d1b57fd7f4c1b493        P003       789 Pine Ln, Springfield, IL
# 3   696bc5c5d1b57fd7f4c1b494        P004        101 Elm St, Springfield, IL
# 4   696bc5c5d1b57fd7f4c1b495        P005    202 Birch Blvd, Springfield, IL
# 5   696bc5c5d1b57fd7f4c1b496        P006      303 Cedar Dr, Springfield, IL
# 6   696bc5c5d1b57fd7f4c1b497        P007     404 Walnut Ct, Springfield, IL
# 7   696bc5c5d1b57fd7f4c1b498        P008       505 Ash Way, Springfield, IL
# 8   696bc5c5d1b57fd7f4c1b499        P009     606 Cherry St, Springfield, IL
# 9   696bc5c5d1b57fd7f4c1b49a        P010    707 Spruce Ave, Springfield, IL
# 10  696bc5c5d1b57fd7f4c1b49b        P011     808 Willow Rd, Springfield, IL
# 11  696bc5c5d1b57fd7f4c1b49c        P012     909 Poplar Pl, Springfield, IL
# 12  696bc5c5d1b57fd7f4c1b49d        P013  111 Magnolia Cir, Springfield, IL
# 13  696bc5c5d1b57fd7f4c1b49e        P014    222 Cypress Dr, Springfield, IL
# 14  696bc5c5d1b57fd7f4c1b49f        P015    333 Redwood Ln, Springfield, IL
#
#      price  bedrooms  bathrooms  square_feet       type  year_built  \
# 0   250000         3        2.0         1800      House        1995
# 1   180000         2        1.0          950      Condo        2005
# 2   450000         4        3.0         2800      House        2018
# 3   120000         1        1.0          700  Apartment        1980
# 4   320000         3        2.5         2100  Townhouse        2010
# 5   550000         5        4.0         3500      House        2022
# 6   195000         2        2.0         1100      Condo        2000
# 7   275000         3        2.0         1600      House        1960
# 8   150000         2        1.0          900  Apartment        1990
# 9   380000         4        2.5         2400      House        2015
# 10  210000         2        2.0         1300  Townhouse        2008
# 11  600000         6        5.0         4200      House        2020
# 12  175000         2        1.5         1000      Condo        1998
# 13  290000         3        2.0         1750      House        1975
# 14  135000         1        1.0          800  Apartment        2012
#
#                                             amenities         agent     status
# 0                      [Garage, Backyard, Central AC]   Sarah Jones  Available
# 1                               [Gym, Pool, Elevator]    Mike Brown       Sold
# 2               [Garage, Pool, Smart Home, Fireplace]   Sarah Jones  Available
# 3                                    [Shared Laundry]   Emily Davis  Available
# 4                    [Garage, Patio, Hardwood Floors]    Mike Brown    Pending
# 5   [Garage, Pool, Home Theater, Wine Cellar, Sola...   Sarah Jones  Available
# 6                                 [Gym, Parking Spot]   Emily Davis       Sold
# 7                                [Backyard, Basement]  David Wilson  Available
# 8                                           [Balcony]  David Wilson  Available
# 9          [Garage, Fenced Yard, Granite Countertops]    Mike Brown  Available
# 10                           [Garage, Community Pool]   Sarah Jones    Pending
# 11             [Garage, Pool, Guest House, Lake View]   Emily Davis  Available
# 12                                [Parking Spot, Gym]  David Wilson       Sold
# 13           [Backyard, Fireplace, Renovated Kitchen]    Mike Brown  Available
# 14                        [Rooftop Access, Concierge]   Sarah Jones  Available

# %% [raw]
# property_type_house =  real_state.find({"type": "House"})
# property_type = pd.DataFrame(property_type_house)
# property_type

# %%
less_than_200k =  real_state.find({'price':{"$lt":200000}})
property_less_200k = pd.DataFrame(less_than_200k)
property_less_200k
# Out:
#                         _id property_id                            address  \
# 0  696bc5c5d1b57fd7f4c1b492        P002        456 Oak St, Springfield, IL
# 1  696bc5c5d1b57fd7f4c1b494        P004        101 Elm St, Springfield, IL
# 2  696bc5c5d1b57fd7f4c1b497        P007     404 Walnut Ct, Springfield, IL
# 3  696bc5c5d1b57fd7f4c1b499        P009     606 Cherry St, Springfield, IL
# 4  696bc5c5d1b57fd7f4c1b49d        P013  111 Magnolia Cir, Springfield, IL
# 5  696bc5c5d1b57fd7f4c1b49f        P015    333 Redwood Ln, Springfield, IL
#
#     price  bedrooms  bathrooms  square_feet       type  year_built  \
# 0  180000         2        1.0          950      Condo        2005
# 1  120000         1        1.0          700  Apartment        1980
# 2  195000         2        2.0         1100      Condo        2000
# 3  150000         2        1.0          900  Apartment        1990
# 4  175000         2        1.5         1000      Condo        1998
# 5  135000         1        1.0          800  Apartment        2012
#
#                      amenities         agent     status
# 0        [Gym, Pool, Elevator]    Mike Brown       Sold
# 1             [Shared Laundry]   Emily Davis  Available
# 2          [Gym, Parking Spot]   Emily Davis       Sold
# 3                    [Balcony]  David Wilson  Available
# 4          [Parking Spot, Gym]  David Wilson       Sold
# 5  [Rooftop Access, Concierge]   Sarah Jones  Available

# %%
property_listed_by_mike = real_state.find({"agent":"Mike Brown"})
mike_lister = pd.DataFrame(property_listed_by_mike)
mike_lister
# Out:
#                         _id property_id                          address  \
# 0  696bc5c5d1b57fd7f4c1b492        P002      456 Oak St, Springfield, IL
# 1  696bc5c5d1b57fd7f4c1b495        P005  202 Birch Blvd, Springfield, IL
# 2  696bc5c5d1b57fd7f4c1b49a        P010  707 Spruce Ave, Springfield, IL
# 3  696bc5c5d1b57fd7f4c1b49e        P014  222 Cypress Dr, Springfield, IL
#
#     price  bedrooms  bathrooms  square_feet       type  year_built  \
# 0  180000         2        1.0          950      Condo        2005
# 1  320000         3        2.5         2100  Townhouse        2010
# 2  380000         4        2.5         2400      House        2015
# 3  290000         3        2.0         1750      House        1975
#
#                                     amenities       agent     status
# 0                       [Gym, Pool, Elevator]  Mike Brown       Sold
# 1            [Garage, Patio, Hardwood Floors]  Mike Brown    Pending
# 2  [Garage, Fenced Yard, Granite Countertops]  Mike Brown  Available
# 3    [Backyard, Fireplace, Renovated Kitchen]  Mike Brown  Available

# %%
try:
    house_and_3bedrooms = real_state.find({"type":"House","bedrooms":3})
    print('connected')
except PyMongoError as e:
    print('not working')
    
house_and_3bedrooms = pd.DataFrame(house_and_3bedrooms)
house_and_3bedrooms
# Out:
# connected
#                         _id property_id                          address  \
# 0  696bc5c5d1b57fd7f4c1b491        P001   123 Maple Ave, Springfield, IL
# 1  696bc5c5d1b57fd7f4c1b498        P008     505 Ash Way, Springfield, IL
# 2  696bc5c5d1b57fd7f4c1b49e        P014  222 Cypress Dr, Springfield, IL
#
#     price  bedrooms  bathrooms  square_feet   type  year_built  \
# 0  250000         3          2         1800  House        1995
# 1  275000         3          2         1600  House        1960
# 2  290000         3          2         1750  House        1975
#
#                                   amenities         agent     status
# 0            [Garage, Backyard, Central AC]   Sarah Jones  Available
# 1                      [Backyard, Basement]  David Wilson  Available
# 2  [Backyard, Fireplace, Renovated Kitchen]    Mike Brown  Available

# %%
try:
    between_2000_and_2015 = real_state.find({"year_built": {"$gt": 2000, "$lt":2015}})
    print('connected')
except PyMongoError as e:
    print(f"MongoDB Error: {e}")


between_2000_and_2015 = pd.DataFrame(between_2000_and_2015)
between_2000_and_2015.sort_values(by='price', ascending=False)
# Out:
# connected
#                         _id property_id                          address  \
# 1  696bc5c5d1b57fd7f4c1b495        P005  202 Birch Blvd, Springfield, IL
# 2  696bc5c5d1b57fd7f4c1b49b        P011   808 Willow Rd, Springfield, IL
# 0  696bc5c5d1b57fd7f4c1b492        P002      456 Oak St, Springfield, IL
# 3  696bc5c5d1b57fd7f4c1b49f        P015  333 Redwood Ln, Springfield, IL
#
#     price  bedrooms  bathrooms  square_feet       type  year_built  \
# 1  320000         3        2.5         2100  Townhouse        2010
# 2  210000         2        2.0         1300  Townhouse        2008
# 0  180000         2        1.0          950      Condo        2005
# 3  135000         1        1.0          800  Apartment        2012
#
#                           amenities        agent     status
# 1  [Garage, Patio, Hardwood Floors]   Mike Brown    Pending
# 2          [Garage, Community Pool]  Sarah Jones    Pending
# 0             [Gym, Pool, Elevator]   Mike Brown       Sold
# 3       [Rooftop Access, Concierge]  Sarah Jones  Available

# %%
find_pool_and_gym = real_state.find({"amenities": {"$in": ["Pool", "Gym"]}})
find_pool_and_gym = pd.DataFrame(find_pool_and_gym)
find_pool_and_gym
# Out:
#                         _id property_id                            address  \
# 0  696bc5c5d1b57fd7f4c1b492        P002        456 Oak St, Springfield, IL
# 1  696bc5c5d1b57fd7f4c1b493        P003       789 Pine Ln, Springfield, IL
# 2  696bc5c5d1b57fd7f4c1b496        P006      303 Cedar Dr, Springfield, IL
# 3  696bc5c5d1b57fd7f4c1b497        P007     404 Walnut Ct, Springfield, IL
# 4  696bc5c5d1b57fd7f4c1b49c        P012     909 Poplar Pl, Springfield, IL
# 5  696bc5c5d1b57fd7f4c1b49d        P013  111 Magnolia Cir, Springfield, IL
#
#     price  bedrooms  bathrooms  square_feet   type  year_built  \
# 0  180000         2        1.0          950  Condo        2005
# 1  450000         4        3.0         2800  House        2018
# 2  550000         5        4.0         3500  House        2022
# 3  195000         2        2.0         1100  Condo        2000
# 4  600000         6        5.0         4200  House        2020
# 5  175000         2        1.5         1000  Condo        1998
#
#                                            amenities         agent     status
# 0                              [Gym, Pool, Elevator]    Mike Brown       Sold
# 1              [Garage, Pool, Smart Home, Fireplace]   Sarah Jones  Available
# 2  [Garage, Pool, Home Theater, Wine Cellar, Sola...   Sarah Jones  Available
# 3                                [Gym, Parking Spot]   Emily Davis       Sold
# 4             [Garage, Pool, Guest House, Lake View]   Emily Davis  Available
# 5                                [Parking Spot, Gym]  David Wilson       Sold

# %%
sorted_by_price = real_state.find({})

sort_price = pd.DataFrame(sorted_by_price).sort_values(by='price',ascending=False)
sort_price
# Out:
#                          _id property_id                            address  \
# 11  696bc5c5d1b57fd7f4c1b49c        P012     909 Poplar Pl, Springfield, IL
# 5   696bc5c5d1b57fd7f4c1b496        P006      303 Cedar Dr, Springfield, IL
# 2   696bc5c5d1b57fd7f4c1b493        P003       789 Pine Ln, Springfield, IL
# 9   696bc5c5d1b57fd7f4c1b49a        P010    707 Spruce Ave, Springfield, IL
# 4   696bc5c5d1b57fd7f4c1b495        P005    202 Birch Blvd, Springfield, IL
# 13  696bc5c5d1b57fd7f4c1b49e        P014    222 Cypress Dr, Springfield, IL
# 7   696bc5c5d1b57fd7f4c1b498        P008       505 Ash Way, Springfield, IL
# 0   696bc5c5d1b57fd7f4c1b491        P001     123 Maple Ave, Springfield, IL
# 10  696bc5c5d1b57fd7f4c1b49b        P011     808 Willow Rd, Springfield, IL
# 6   696bc5c5d1b57fd7f4c1b497        P007     404 Walnut Ct, Springfield, IL
# 1   696bc5c5d1b57fd7f4c1b492        P002        456 Oak St, Springfield, IL
# 12  696bc5c5d1b57fd7f4c1b49d        P013  111 Magnolia Cir, Springfield, IL
# 8   696bc5c5d1b57fd7f4c1b499        P009     606 Cherry St, Springfield, IL
# 14  696bc5c5d1b57fd7f4c1b49f        P015    333 Redwood Ln, Springfield, IL
# 3   696bc5c5d1b57fd7f4c1b494        P004        101 Elm St, Springfield, IL
#
#      price  bedrooms  bathrooms  square_feet       type  year_built  \
# 11  600000         6        5.0         4200      House        2020
# 5   550000         5        4.0         3500      House        2022
# 2   450000         4        3.0         2800      House        2018
# 9   380000         4        2.5         2400      House        2015
# 4   320000         3        2.5         2100  Townhouse        2010
# 13  290000         3        2.0         1750      House        1975
# 7   275000         3        2.0         1600      House        1960
# 0   250000         3        2.0         1800      House        1995
# 10  210000         2        2.0         1300  Townhouse        2008
# 6   195000         2        2.0         1100      Condo        2000
# 1   180000         2        1.0          950      Condo        2005
# 12  175000         2        1.5         1000      Condo        1998
# 8   150000         2        1.0          900  Apartment        1990
# 14  135000         1        1.0          800  Apartment        2012
# 3   120000         1        1.0          700  Apartment        1980
#
#                                             amenities         agent     status
# 11             [Garage, Pool, Guest House, Lake View]   Emily Davis  Available
# 5   [Garage, Pool, Home Theater, Wine Cellar, Sola...   Sarah Jones  Available
# 2               [Garage, Pool, Smart Home, Fireplace]   Sarah Jones  Available
# 9          [Garage, Fenced Yard, Granite Countertops]    Mike Brown  Available
# 4                    [Garage, Patio, Hardwood Floors]    Mike Brown    Pending
# 13           [Backyard, Fireplace, Renovated Kitchen]    Mike Brown  Available
# 7                                [Backyard, Basement]  David Wilson  Available
# 0                      [Garage, Backyard, Central AC]   Sarah Jones  Available
# 10                           [Garage, Community Pool]   Sarah Jones    Pending
# 6                                 [Gym, Parking Spot]   Emily Davis       Sold
# 1                               [Gym, Pool, Elevator]    Mike Brown       Sold
# 12                                [Parking Spot, Gym]  David Wilson       Sold
# 8                                           [Balcony]  David Wilson  Available
# 14                        [Rooftop Access, Concierge]   Sarah Jones  Available
# 3                                    [Shared Laundry]   Emily Davis  Available

# %%
top_3 = sort_price.head(3)

top_3
# Out:
#                          _id property_id                         address  \
# 11  696bc5c5d1b57fd7f4c1b49c        P012  909 Poplar Pl, Springfield, IL
# 5   696bc5c5d1b57fd7f4c1b496        P006   303 Cedar Dr, Springfield, IL
# 2   696bc5c5d1b57fd7f4c1b493        P003    789 Pine Ln, Springfield, IL
#
#      price  bedrooms  bathrooms  square_feet   type  year_built  \
# 11  600000         6        5.0         4200  House        2020
# 5   550000         5        4.0         3500  House        2022
# 2   450000         4        3.0         2800  House        2018
#
#                                             amenities        agent     status
# 11             [Garage, Pool, Guest House, Lake View]  Emily Davis  Available
# 5   [Garage, Pool, Home Theater, Wine Cellar, Sola...  Sarah Jones  Available
# 2               [Garage, Pool, Smart Home, Fireplace]  Sarah Jones  Available

# %%
oldest = real_state.find_one(sort=[("year_built", 1)]) 
oldest = pd.DataFrame(oldest)
oldest
# Out:
#                         _id property_id                       address   price  \
# 0  696bc5c5d1b57fd7f4c1b498        P008  505 Ash Way, Springfield, IL  275000
# 1  696bc5c5d1b57fd7f4c1b498        P008  505 Ash Way, Springfield, IL  275000
#
#    bedrooms  bathrooms  square_feet   type  year_built amenities  \
# 0         3          2         1600  House        1960  Backyard
# 1         3          2         1600  House        1960  Basement
#
#           agent     status
# 0  David Wilson  Available
# 1  David Wilson  Available

# %%
average_price = real_state.find({})

average_price = pd.DataFrame(average_price)

average_price = average_price['price'].mean()

average_price
print(f'the average price of all the properties was {average_price:.2f}')
# Out:
# the average price of all the properties was 285333.33

# %%
groupby_type =real_state.find({})
groupby_type = pd.DataFrame(groupby_type)
groupby_type = groupby_type.groupby('type').size().reset_index().rename(columns={0:'count'}).sort_values(by='count', ascending=False)
groupby_type
# Out:
#         type  count
# 2      House      7
# 0  Apartment      3
# 1      Condo      3
# 3  Townhouse      2

# %%
groupby_type.plot(kind='bar',x='type',y='count',title='Count of Properties by Type',color=['blue','red','yellow','green'])
plt.legend().set_visible(False)
plt.show()

# %%
real_state.update_one({'property_id':'P001' },{"$set":{'price':11000}})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
