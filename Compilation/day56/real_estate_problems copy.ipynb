# %% [markdown]
# # 🏠 Real Estate Data Analysis - Practice Problems
#
# This notebook contains **12 practice problems** to help you learn data analysis using a real estate dataset.
#
# **Dataset:** `real_estate_data.csv`
#
# **Columns:**
# - `property_id` - Unique identifier
# - `address` - Street address
# - `city`, `state` - Location
# - `price` - Listing/Sale price
# - `bedrooms`, `bathrooms` - Number of beds/baths
# - `sqft` - Square footage
# - `lot_size` - Lot size in sqft
# - `year_built` - Year property was built
# - `property_type` - Single Family, Condo, Townhouse
# - `listing_status` - Active, Pending, Sold
# - `days_on_market` - Days listed
# - `agent_name` - Real estate agent
# - `sale_date` - Date sold (if applicable)

# %%
# Setup - Run this cell first!
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('real_estate_data.csv')

# Preview the data
df.head()
# Out:
#    property_id           address           city state    price  bedrooms  \
# 0            1    123 Oak Street    Los Angeles    CA   850000         4
# 1            2  456 Maple Avenue  San Francisco    CA  1250000         3
# 2            3     789 Pine Road        Seattle    WA   725000         3
# 3            4    321 Cedar Lane       Portland    OR   485000         2
# 4            5   654 Birch Court         Denver    CO   595000         4
#
#    bathrooms  sqft  lot_size  year_built  property_type listing_status  \
# 0          3  2200      5500        2005  Single Family           Sold
# 1          2  1800      3200        1998          Condo           Sold
# 2          2  1650      4800        2010  Single Family         Active
# 3          1  1200      2800        1985      Townhouse           Sold
# 4          2  1950      6200        2015  Single Family         Active
#
#    days_on_market     agent_name   sale_date
# 0              45  Sarah Johnson  2024-01-15
# 1              30   Michael Chen  2024-01-20
# 2              22    Emily Davis         NaN
# 3              60   James Wilson  2024-02-01
# 4              15  Lisa Martinez         NaN

# %%
# Check the dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   property_id     50 non-null     int64
#  1   address         50 non-null     object
#  2   city            50 non-null     object
#  3   state           50 non-null     object
#  4   price           50 non-null     int64
#  5   bedrooms        50 non-null     int64
#  6   bathrooms       50 non-null     int64
#  7   sqft            50 non-null     int64
#  8   lot_size        50 non-null     int64
#  9   year_built      50 non-null     int64
#  10  property_type   50 non-null     object
#  11  listing_status  50 non-null     object
#  12  days_on_market  50 non-null     int64
#  13  agent_name      50 non-null     object
#  14  sale_date       23 non-null     object
# dtypes: int64(8), object(7)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# property_id        0
# address            0
# city               0
# state              0
# price              0
# bedrooms           0
# bathrooms          0
# sqft               0
# lot_size           0
# year_built         0
# property_type      0
# listing_status     0
# days_on_market     0
# agent_name         0
# sale_date         27
# price_per_sqft     0
# price_tier         0
# dtype: int64

# %% [markdown]
# ---
# ## Problem 1: Basic Statistics
#
# **Question:** What is the average, minimum, and maximum price of all properties in the dataset?

# %%
# Your code here
df1 = df.agg({
    'price': ['mean', 'min', 'max']
})
df1
# Out:
#           price
# mean   486000.0
# min    245000.0
# max   1450000.0

# %% [markdown]
# ---
# ## Problem 2: Filtering Data
#
# **Question:** Find all properties in California (CA) that are priced above $800,000. Display the address, city, price, and bedrooms.

# %%
# Your code here
california_800k = df[(df['state'] == 'CA') & (df['price'] > 800000)]
california_800k[['address','city','price','bedrooms']].sort_values(by='price', ascending=False).head()
# Out:
#               address           city    price  bedrooms
# 1    456 Maple Avenue  San Francisco  1250000         3
# 19   834 Alder Avenue       San Jose  1100000         4
# 8   369 Redwood Place      San Diego   925000         4
# 0      123 Oak Street    Los Angeles   850000         4

# %% [markdown]
# ---
# ## Problem 3: Grouping and Aggregation
#
# **Question:** Calculate the average property price for each state. Sort the results from highest to lowest average price.

# %%
# Your code here
average_price_each_state = df.groupby('state')['price'].mean().sort_values(ascending=False)
average_price_each_state
# Out:
# state
# MA    890000.000000
# CA    865833.333333
# NY    847500.000000
# WA    725000.000000
# IL    525000.000000
# CO    520000.000000
# FL    498333.333333
# UT    485000.000000
# OR    485000.000000
# MN    465000.000000
# MD    425000.000000
# RI    415000.000000
# TX    410000.000000
# AZ    403333.333333
# CT    395000.000000
# GA    395000.000000
# PA    390000.000000
# ID    385000.000000
# NV    382500.000000
# NC    372500.000000
# TN    365000.000000
# VA    360000.000000
# MO    340000.000000
# KY    315000.000000
# NM    310000.000000
# OH    305000.000000
# IN    295000.000000
# WI    285000.000000
# NE    275000.000000
# OK    265000.000000
# Name: price, dtype: float64

# %% [markdown]
# ---
# ## Problem 4: Value Counts
#
# **Question:** How many properties are there for each listing status (Active, Pending, Sold)? Show both the count and percentage.

# %%
properties_listing_status = (
    df['listing_status']
    .value_counts()
    .reset_index(name='count')
)
properties_listing_status
# Out:
#   listing_status  count
# 0           Sold     23
# 1         Active     18
# 2        Pending      9

# %%
properties_listing_status.plot(
    kind='pie',
    xlabel='listing_status',
    ylabel='count',
    title='Listing Status Distribution',
    
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 properties_listing_status.plot(
#       2     kind='pie',
#       3     xlabel='listing_status',
#       4     ylabel='count',
#       5     title='Listing Status Distribution',
#       6
#       7 )
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\plotting\_core.py:981, in PlotAccessor.__call__(self, *args, **kwargs)
#     979 if isinstance(data, ABCDataFrame):
#     980     if y is None and kwargs.get("subplots") is False:
# --> 981         raise ValueError(
#     982             f"{kind} requires either y column or 'subplots=True'"
#     983         )
#     984     if y is not None:
#     985         if is_integer(y) and not data.columns._holds_integer():
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
properties_listing_status.plot(
    kind='pie',
    y='count',
    labels=properties_listing_status['listing_status'],
    autopct='%1.1f%%',
    title='Listing Status Distribution',
    legend=False
)
# Out:
# <Axes: title={'center': 'Listing Status Distribution'}, ylabel='count'>

# %% [markdown]
# ---
# ## Problem 5: Creating New Columns
#
# **Question:** Create a new column called `price_per_sqft` that calculates the price per square foot for each property. Then find the top 5 properties with the highest price per sqft.

# %%
# Your code here
df['price_per_sqft'] = (df['price'] / df['sqft']).round(2)
df.sort_values(by='price_per_sqft', ascending=False).head()
# Out:
#     property_id             address           city state    price  bedrooms  \
# 15           16  489 Chestnut Drive       New York    NY  1450000         2
# 1             2    456 Maple Avenue  San Francisco    CA  1250000         3
# 14           15   378 Walnut Street         Boston    MA   890000         3
# 19           20    834 Alder Avenue       San Jose    CA  1100000         4
# 2             3       789 Pine Road        Seattle    WA   725000         3
#
#     bathrooms  sqft  lot_size  year_built  property_type listing_status  \
# 15          2  1400         0        2020          Condo           Sold
# 1           2  1800      3200        1998          Condo           Sold
# 14          2  1650      2800        1988          Condo         Active
# 19          3  2150      4800        2016  Single Family           Sold
# 2           2  1650      4800        2010  Single Family         Active
#
#     days_on_market       agent_name   sale_date  price_per_sqft price_tier
# 15              38     Andrew Lewis  2024-02-08         1035.71     Luxury
# 1               30     Michael Chen  2024-01-20          694.44     Luxury
# 14              12  Stephanie Clark         NaN          539.39     Luxury
# 19              40     Justin Young  2024-02-12          511.63     Luxury
# 2               22      Emily Davis         NaN          439.39     Luxury

# %% [markdown]
# ---
# ## Problem 6: Multiple Conditions Filter
#
# **Question:** Find all Single Family homes with 4+ bedrooms that are priced under $500,000. Which states have these affordable family homes?

# %%
# Your code here
df2 = df[(df['bedrooms'] >= 4) & (df['price'] <= 500_000) & (df['property_type'] =='Single Family')] 
df2[['city','state','price','bedrooms','property_type']]
# Out:
#                 city state   price  bedrooms  property_type
# 11         Nashville    TN  445000         4  Single Family
# 16            Dallas    TX  475000         4  Single Family
# 21           Orlando    FL  425000         4  Single Family
# 23       Minneapolis    MN  465000         4  Single Family
# 26    Salt Lake City    UT  485000         4  Single Family
# 29      Indianapolis    IN  295000         4  Single Family
# 32       Albuquerque    NM  310000         4  Single Family
# 35        Louisville    KY  315000         4  Single Family
# 38        Pittsburgh    PA  345000         4  Single Family
# 41         Riverside    CA  495000         4  Single Family
# 43              Reno    NV  425000         4  Single Family
# 45  Colorado Springs    CO  445000         4  Single Family
# 47          Hartford    CT  395000         4  Single Family

# %% [markdown]
# ---
# ## Problem 7: Handling Missing Values
#
# **Question:** How many properties have NOT been sold (have missing sale_date)? What percentage of total properties does this represent?

# %%
# Your code here
property_not_sold = df[df['listing_status'] != 'Sold']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 3
#       1 # Your code here
#       2 property_not_sold = df[df['listing_status'] != 'Sold']
# ----> 3 property_not_sold.sum()
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)  11695     **kwargs,
#   11696 ):
# > 11697     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11698     return result.__finalize__(self, method="sum")
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12571, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12563 def sum(
#   12564     self,
#   12565     axis: Axis | None = 0,
#    (...)  12569     **kwargs,
#   12570 ):
# > 12571     return self._min_count_stat_function(
#   12572         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12573     )
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12554, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12551 elif axis is lib.no_default:
#   12552     axis = 0
# > 12554 return self._reduce(
#   12555     func,
#   12556     name=name,
#   12557     axis=axis,
#   12558     skipna=skipna,
#   12559     numeric_only=numeric_only,
#   12560     min_count=min_count,
#   12561 )
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:11497, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11495     dtype_has_keepdims[values.dtype] = has_keepdims
#   11496 if has_keepdims:
# > 11497     return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   11498 else:
#   11499     warnings.warn(
#   11500         f"{type(values)}._reduce will require a `keepdims` parameter "
#   11501         "in the future",
#   11502         FutureWarning,
#   11503         stacklevel=find_stack_level(),
#   11504     )
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\categorical.py:2391, in Categorical._reduce(self, name, skipna, keepdims, **kwargs)
#    2388 def _reduce(
#    2389     self, name: str, *, skipna: bool = True, keepdims: bool = False, **kwargs
#    2390 ):
# -> 2391     result = super()._reduce(name, skipna=skipna, keepdims=keepdims, **kwargs)
#    2392     if name in ["argmax", "argmin"]:
#    2393         # don't wrap in Categorical!
#    2394         return result
#
# File c:\Users\francis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\base.py:1954, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    1952 meth = getattr(self, name, None)
#    1953 if meth is None:
# -> 1954     raise TypeError(
#    1955         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1956         f"does not support reduction '{name}'"
#    1957     )
#    1958 result = meth(skipna=skipna, **kwargs)
#    1959 if keepdims:
#
# TypeError: 'Categorical' with dtype category does not support reduction 'sum'

# %%
# Count properties NOT sold (missing sale_date)
not_sold_count = df['sale_date'].isna().sum()

# Total properties
total_properties = len(df)

# Percentage formula
percentage_not_sold = (not_sold_count / total_properties) * 100

# Display results
print(f"Properties not sold: {not_sold_count}")
print(f"Total properties: {total_properties}")
print(f"Percentage not sold: {percentage_not_sold:.2f}%")
# Out:
# Properties not sold: 27
# Total properties: 50
# Percentage not sold: 54.00%

# %% [markdown]
# ---
# ## Problem 8: Groupby with Multiple Aggregations
#
# **Question:** For each property type, calculate:
# - Count of properties
# - Average price
# - Average square footage
# - Average days on market

# %%
# Your code here

property_type_data = df.groupby('property_type').agg(
    total_properties = ('property_type', 'count'),
    average_pruce = ('price','mean'),
    average_square_footage = ('sqft','mean'),
    avg_days_on_market = ('days_on_market','mean')
).sort_values(by='total_properties',ascending=False)

property_type_data
# Out:
#                total_properties  average_pruce  average_square_footage  \
# property_type
# Single Family                39  440769.230769             1756.410256
# Townhouse                     6  417500.000000             1516.666667
# Condo                         5  921000.000000             1600.000000
#
#                avg_days_on_market
# property_type
# Single Family           34.974359
# Townhouse               34.000000
# Condo                   35.400000

# %% [markdown]
# ---
# ## Problem 9: Conditional Column Creation
#
# **Question:** Create a new column called `price_tier` that categorizes properties as:
# - 'Budget' if price < $350,000
# - 'Mid-Range' if price is between $350,000 and $600,000
# - 'Luxury' if price > $600,000
#
# Then count how many properties are in each tier.

# %%
# Your code here
bins = [0, 350_000, 600_000, float('inf')]
labels = ['Budget', 'Mid-Range', 'Luxury']


df['price_tier'] = pd.cut(df['price'],bins=bins,labels=labels,include_lowest=True)
df.head()
# Out:
#    property_id           address           city state    price  bedrooms  \
# 0            1    123 Oak Street    Los Angeles    CA   850000         4
# 1            2  456 Maple Avenue  San Francisco    CA  1250000         3
# 2            3     789 Pine Road        Seattle    WA   725000         3
# 3            4    321 Cedar Lane       Portland    OR   485000         2
# 4            5   654 Birch Court         Denver    CO   595000         4
#
#    bathrooms  sqft  lot_size  year_built  property_type listing_status  \
# 0          3  2200      5500        2005  Single Family           Sold
# 1          2  1800      3200        1998          Condo           Sold
# 2          2  1650      4800        2010  Single Family         Active
# 3          1  1200      2800        1985      Townhouse           Sold
# 4          2  1950      6200        2015  Single Family         Active
#
#    days_on_market     agent_name   sale_date  price_per_sqft price_tier
# 0              45  Sarah Johnson  2024-01-15          386.36     Luxury
# 1              30   Michael Chen  2024-01-20          694.44     Luxury
# 2              22    Emily Davis         NaN          439.39     Luxury
# 3              60   James Wilson  2024-02-01          404.17  Mid-Range
# 4              15  Lisa Martinez         NaN          305.13  Mid-Range

# %% [markdown]
# ---
# ## Problem 10: Top Performers Analysis
#
# **Question:** Which real estate agent has sold the most properties? Also find the total sales value for the top 5 agents by number of sales.

# %%
count_unique_name = df['agent_name'].nunique()
print(count_unique_name)
# Out:
# 50

# %%
# Your code here
top_performer = df.groupby('agent_name').agg({
    'listing_status':'count'
    }).reset_index()
top_performer = top_performer.sort_values('listing_status',ascending=False)
top_performer
# Out:
#           agent_name  listing_status
# 0        Alex Martin               1
# 1        Alexis King               1
# 2      Amanda Taylor               1
# 3        Amber Scott               1
# 4       Andrew Lewis               1
# 5        Ashley King               1
# 6      Austin Walker               1
# 7       Brandon Hall               1
# 8      Brandon Lewis               1
# 9     Brittany Adams               1
# 10     Cameron Young               1
# 11       Casey Adams               1
# 12      Chris Thomas               1
# 13   Christopher Lee               1
# 14    Courtney White               1
# 15     Daniel Harris               1
# 16    David Anderson               1
# 17      Derek Harris               1
# 18         Drew Hill               1
# 19     Dylan Jackson               1
# 20       Emily Davis               1
# 21      Jacob Nelson               1
# 22      James Wilson               1
# 23      Jamie Nelson               1
# 24    Jennifer White               1
# 25  Jessica Robinson               1
# 26     Jordan Wright               1
# 27      Justin Young               1
# 28      Kayla Thomas               1
# 29   Kevin Rodriguez               1
# 30      Lauren Clark               1
# 31     Lisa Martinez               1
# 32       Megan Allen               1
# 33      Michael Chen               1
# 34   Michelle Garcia               1
# 35      Morgan Green               1
# 36       Morgan Hall               1
# 37      Nathan Moore               1
# 38     Nicole Walker               1
# 39         Pat Moore               1
# 40   Rachel Thompson               1
# 41      Robert Brown               1
# 42       Ryan Wright               1
# 43     Samantha Hill               1
# 44     Sarah Johnson               1
# 45   Stephanie Clark               1
# 46      Taylor Scott               1
# 47     Timothy Green               1
# 48      Tyler Martin               1
# 49  Victoria Jackson               1

# %% [markdown]
# ---
# ## Problem 11: Correlation Analysis
#
# **Question:** What is the correlation between:
# 1. Price and Square Footage
# 2. Price and Number of Bedrooms
# 3. Days on Market and Price
#
# Which factor has the strongest correlation with price?

# %%
# Your code here

# %% [markdown]
# ---
# ## Problem 12: Property Age Analysis
#
# **Question:** Create a column called `property_age` (current year 2024 minus year_built). Then:
# 1. What is the average age of properties by property type?
# 2. Find properties built in the last 10 years (2014 or later) that are still Active. How many are there and what's their average price?

# %%
# Your code here

# %% [markdown]
# ---
# ## 🎉 Bonus Challenge
#
# **Question:** Create a comprehensive market analysis by state that includes:
# - Total number of properties
# - Number of sold properties
# - Average sale price
# - Median days on market
# - Most common property type
#
# Sort by total number of properties descending.

# %%
# Your code here
