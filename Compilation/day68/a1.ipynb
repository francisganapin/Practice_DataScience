# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('shopify_orders.csv')

# %%
mean_total = df['Total'].mean()
std_total = df['Total'].std()
df['z_score'] = (df['Total'] - mean_total) / std_total

# %%
print(f'{mean_total} total mean')
print(f'{std_total} standard deviation total')
# Out:
# 6176.2 total mean
# 8846.438898431023 standard deviation total

# %%
# Flag suspicious orders
df['Fraud_Flag_ZScore'] = np.where(abs(df['z_score']) > 2, 'SUSPICIOUS', 'OK')

# %%
print(df[df['Fraud_Flag_ZScore'] == 'SUSPICIOUS'])
# Out:
#      Name                      Email Financial Status Fulfillment Status  \
# 19  #1020     test.buyer777@mail.com             paid        unfulfilled
# 42  #1043     test.buyer777@mail.com             paid        unfulfilled
# 48  #1049  fakeemail001@tempmail.com             paid        unfulfilled
#
#       Total  Subtotal  Shipping  Discount Amount           Created at  \
# 19  25000.0   24200.0     800.0              0.0  2026-01-10 04:10:00
# 42  26000.0   25200.0     800.0              0.0  2026-01-19 04:50:00
# 48  24000.0   23200.0     800.0              0.0  2026-01-21 01:45:00
#
#    Billing City Billing Province Billing Country  Shipping City  \
# 19     San Juan     Metro Manila              PH  Cotabato City
# 42     San Juan     Metro Manila              PH        Dipolog
# 48  Quezon City     Metro Manila              PH       Valencia
#
#       Shipping Province Shipping Country Payment Method  Lineitem quantity  \
# 19          Maguindanao               PH    Credit Card                 15
# 42  Zamboanga del Norte               PH    Credit Card                 16
# 48             Bukidnon               PH    Credit Card                 14
#
#     Lineitem price   z_score Fraud_Flag_ZScore
# 19         1613.33  2.127839        SUSPICIOUS
# 42         1575.00  2.240879        SUSPICIOUS
# 48         1657.14  2.014799        SUSPICIOUS

# %%
df.head(3)
# Out:
#     Name                   Email Financial Status Fulfillment Status   Total  \
# 0  #1001  maria.santos@gmail.com             paid          fulfilled  1250.0
# 1  #1002    john.reyes@yahoo.com             paid          fulfilled   850.0
# 2  #1003     anna.cruz@gmail.com             paid          fulfilled  2100.0
#
#    Subtotal  Shipping  Discount Amount           Created at Billing City  \
# 0    1100.0     150.0              0.0  2026-01-02 10:23:00   Davao City
# 1     750.0     100.0              0.0  2026-01-02 14:15:00    Cebu City
# 2    1950.0     150.0              0.0  2026-01-03 09:45:00       Manila
#
#   Billing Province Billing Country Shipping City Shipping Province  \
# 0    Davao del Sur              PH    Davao City     Davao del Sur
# 1             Cebu              PH     Cebu City              Cebu
# 2     Metro Manila              PH        Manila      Metro Manila
#
#   Shipping Country Payment Method  Lineitem quantity  Lineitem price  \
# 0               PH    Credit Card                  2           550.0
# 1               PH    Credit Card                  1           750.0
# 2               PH         PayPal                  3           650.0
#
#     z_score Fraud_Flag_ZScore
# 0 -0.556857                OK
# 1 -0.602073                OK
# 2 -0.460773                OK

# %%
Q1 = df['Total'].quantile(0.25)
Q3 = df['Total'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df['Fraud_Flag_IQR'] = np.where(
    (df['Total'] < lower) | (df['Total'] > upper), 
    'OUTLIER','OK'
)

# %%
print(f"Lower Bound:{lower},Upper Bound:{upper}")
print(df[df['Fraud_Flag_IQR']== 'OUTLIER'])
# Out:
# Lower Bound:-15712.5,Upper Bound:28547.5
# Empty DataFrame
# Columns: [Name, Email, Financial Status, Fulfillment Status, Total, Subtotal, Shipping, Discount Amount, Created at, Billing City, Billing Province, Billing Country, Shipping City, Shipping Province, Shipping Country, Payment Method, Lineitem quantity, Lineitem price, z_score, Fraud_Flag_ZScore, Fraud_Flag_IQR]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.head(5)
# Out:
#     Name                      Email Financial Status Fulfillment Status  \
# 0  #1001     maria.santos@gmail.com             paid          fulfilled
# 1  #1002       john.reyes@yahoo.com             paid          fulfilled
# 2  #1003        anna.cruz@gmail.com             paid          fulfilled
# 3  #1004  fakeemail001@tempmail.com             paid        unfulfilled
# 4  #1005     pedro.garcia@gmail.com             paid          fulfilled
#
#      Total  Subtotal  Shipping  Discount Amount           Created at  \
# 0   1250.0    1100.0     150.0              0.0  2026-01-02 10:23:00
# 1    850.0     750.0     100.0              0.0  2026-01-02 14:15:00
# 2   2100.0    1950.0     150.0              0.0  2026-01-03 09:45:00
# 3  18500.0   18000.0     500.0              0.0  2026-01-03 02:13:00
# 4   1500.0    1350.0     150.0              0.0  2026-01-04 11:30:00
#
#      Billing City  ... Billing Country   Shipping City  Shipping Province  \
# 0      Davao City  ...              PH      Davao City      Davao del Sur
# 1       Cebu City  ...              PH       Cebu City               Cebu
# 2          Manila  ...              PH          Manila       Metro Manila
# 3          Manila  ...              PH  Cagayan de Oro   Misamis Oriental
# 4  Zamboanga City  ...              PH  Zamboanga City  Zamboanga del Sur
#
#   Shipping Country Payment Method Lineitem quantity  Lineitem price   z_score  \
# 0               PH    Credit Card                 2           550.0 -0.556857
# 1               PH    Credit Card                 1           750.0 -0.602073
# 2               PH         PayPal                 3           650.0 -0.460773
# 3               PH    Credit Card                10          1800.0  1.393080
# 4               PH          GCash                 2           675.0 -0.528597
#
#    Fraud_Flag_ZScore Fraud_Flag_IQR
# 0                 OK             OK
# 1                 OK             OK
# 2                 OK             OK
# 3                 OK             OK
# 4                 OK             OK
#
# [5 rows x 21 columns]

# %%
email_counts = df['Email'].value_counts()
df['Order_Count'] = df['Email'].map(email_counts)

df['Fraud_Flag_Frequency'] = np.where(
    df['Order_Count'] > 3, 'FREQUENT','OK'
)

print(df[df['Fraud_Flag_Frequency']== 'FREQUENT'])
# Out:
#      Name                         Email Financial Status Fulfillment Status  \
# 3   #1004     fakeemail001@tempmail.com             paid        unfulfilled
# 6   #1007     fakeemail001@tempmail.com             paid        unfulfilled
# 10  #1011  suspicious.buyer99@proton.me             paid        unfulfilled
# 13  #1014     fakeemail001@tempmail.com             paid        unfulfilled
# 17  #1018  suspicious.buyer99@proton.me             paid        unfulfilled
# 22  #1023     fakeemail001@tempmail.com             paid        unfulfilled
# 24  #1025  discount.hunter@fakemail.net             paid          fulfilled
# 27  #1028  suspicious.buyer99@proton.me             paid        unfulfilled
# 28  #1029  discount.hunter@fakemail.net             paid          fulfilled
# 34  #1035     fakeemail001@tempmail.com             paid        unfulfilled
# 37  #1038  discount.hunter@fakemail.net             paid          fulfilled
# 38  #1039  suspicious.buyer99@proton.me             paid        unfulfilled
# 45  #1046  discount.hunter@fakemail.net             paid          fulfilled
# 48  #1049     fakeemail001@tempmail.com             paid        unfulfilled
#
#       Total  Subtotal  Shipping  Discount Amount           Created at  \
# 3   18500.0   18000.0     500.0              0.0  2026-01-03 02:13:00
# 6   22000.0   21500.0     500.0              0.0  2026-01-04 03:05:00
# 10  15200.0   14500.0     700.0              0.0  2026-01-06 01:30:00
# 13  19800.0   19000.0     800.0              0.0  2026-01-07 02:48:00
# 17  16500.0   15800.0     700.0              0.0  2026-01-09 03:22:00
# 22  21000.0   20200.0     800.0              0.0  2026-01-11 01:55:00
# 24    350.0    1200.0     150.0           1000.0  2026-01-12 16:30:00
# 27  17800.0   17000.0     800.0              0.0  2026-01-13 02:05:00
# 28    200.0    1500.0     100.0           1400.0  2026-01-14 12:20:00
# 34  20500.0   19700.0     800.0              0.0  2026-01-16 01:20:00
# 37    150.0    1800.0     150.0           1800.0  2026-01-17 11:10:00
# 38  19000.0   18200.0     800.0              0.0  2026-01-18 02:35:00
# 45    100.0    2000.0     100.0           2000.0  2026-01-20 13:55:00
# 48  24000.0   23200.0     800.0              0.0  2026-01-21 01:45:00
#
#    Billing City  ...   Shipping Province Shipping Country Payment Method  \
# 3        Manila  ...    Misamis Oriental               PH    Credit Card
# 6   Quezon City  ...      South Cotabato               PH    Credit Card
# 10       Makati  ...       Davao del Sur               PH    Credit Card
# 13  Mandaluyong  ...     Davao del Norte               PH    Credit Card
# 17        Pasay  ...     Lanao del Norte               PH    Credit Card
# 22     Marikina  ...   Zamboanga del Sur               PH    Credit Card
# 24  Quezon City  ...        Metro Manila               PH    Credit Card
# 27       Taguig  ...    Agusan del Norte               PH    Credit Card
# 28       Manila  ...        Metro Manila               PH    Credit Card
# 34        Pasig  ...   Surigao del Norte               PH    Credit Card
# 37    Cebu City  ...                Cebu               PH    Credit Card
# 38  Mandaluyong  ...  Misamis Occidental               PH    Credit Card
# 45   Davao City  ...       Davao del Sur               PH    Credit Card
# 48  Quezon City  ...            Bukidnon               PH    Credit Card
#
#    Lineitem quantity Lineitem price   z_score  Fraud_Flag_ZScore  \
# 3                 10        1800.00  1.393080                 OK
# 6                 12        1791.67  1.788720                 OK
# 10                 8        1812.50  1.020049                 OK
# 13                11        1727.27  1.540032                 OK
# 17                 9        1755.56  1.167001                 OK
# 22                13        1553.85  1.675680                 OK
# 24                 2         600.00 -0.658593                 OK
# 27                10        1700.00  1.313952                 OK
# 28                 3         500.00 -0.675549                 OK
# 34                12        1641.67  1.619160                 OK
# 37                 3         600.00 -0.681201                 OK
# 38                11        1654.55  1.449600                 OK
# 45                 4         500.00 -0.686853                 OK
# 48                14        1657.14  2.014799         SUSPICIOUS
#
#     Fraud_Flag_IQR  Order_Count Fraud_Flag_Frequency
# 3               OK            6             FREQUENT
# 6               OK            6             FREQUENT
# 10              OK            4             FREQUENT
# 13              OK            6             FREQUENT
# 17              OK            4             FREQUENT
# 22              OK            6             FREQUENT
# 24              OK            4             FREQUENT
# 27              OK            4             FREQUENT
# 28              OK            4             FREQUENT
# 34              OK            6             FREQUENT
# 37              OK            4             FREQUENT
# 38              OK            4             FREQUENT
# 45              OK            4             FREQUENT
# 48              OK            6             FREQUENT
#
# [14 rows x 23 columns]

# %%
df['Address_Mismatch'] = np.where(
    df['Billing City'] != df['Shipping City'],
    'MISMATCH','MATCH'
)

# %%
df['Created at'] = pd.to_datetime(df['Created at'])
df['Order_Hour'] = df['Created at'].dt.hour

df['Fraud_Flag_Time'] = np.where(
    df['Order_Hour'].between(1,5),
    'ODD_HOUR','OK'
)

print(df[df['Fraud_Flag_Time'] == 'ODD_HOUR'])
# Out:
#      Name                         Email Financial Status Fulfillment Status  \
# 3   #1004     fakeemail001@tempmail.com             paid        unfulfilled
# 6   #1007     fakeemail001@tempmail.com             paid        unfulfilled
# 10  #1011  suspicious.buyer99@proton.me             paid        unfulfilled
# 13  #1014     fakeemail001@tempmail.com             paid        unfulfilled
# 17  #1018  suspicious.buyer99@proton.me             paid        unfulfilled
# 19  #1020        test.buyer777@mail.com             paid        unfulfilled
# 22  #1023     fakeemail001@tempmail.com             paid        unfulfilled
# 27  #1028  suspicious.buyer99@proton.me             paid        unfulfilled
# 31  #1032        test.buyer777@mail.com             paid        unfulfilled
# 34  #1035     fakeemail001@tempmail.com             paid        unfulfilled
# 38  #1039  suspicious.buyer99@proton.me             paid        unfulfilled
# 42  #1043        test.buyer777@mail.com             paid        unfulfilled
# 48  #1049     fakeemail001@tempmail.com             paid        unfulfilled
#
#       Total  Subtotal  Shipping  Discount Amount          Created at  \
# 3   18500.0   18000.0     500.0              0.0 2026-01-03 02:13:00
# 6   22000.0   21500.0     500.0              0.0 2026-01-04 03:05:00
# 10  15200.0   14500.0     700.0              0.0 2026-01-06 01:30:00
# 13  19800.0   19000.0     800.0              0.0 2026-01-07 02:48:00
# 17  16500.0   15800.0     700.0              0.0 2026-01-09 03:22:00
# 19  25000.0   24200.0     800.0              0.0 2026-01-10 04:10:00
# 22  21000.0   20200.0     800.0              0.0 2026-01-11 01:55:00
# 27  17800.0   17000.0     800.0              0.0 2026-01-13 02:05:00
# 31  23500.0   22800.0     700.0              0.0 2026-01-15 03:40:00
# 34  20500.0   19700.0     800.0              0.0 2026-01-16 01:20:00
# 38  19000.0   18200.0     800.0              0.0 2026-01-18 02:35:00
# 42  26000.0   25200.0     800.0              0.0 2026-01-19 04:50:00
# 48  24000.0   23200.0     800.0              0.0 2026-01-21 01:45:00
#
#    Billing City  ... Lineitem quantity Lineitem price   z_score  \
# 3        Manila  ...                10        1800.00  1.393080
# 6   Quezon City  ...                12        1791.67  1.788720
# 10       Makati  ...                 8        1812.50  1.020049
# 13  Mandaluyong  ...                11        1727.27  1.540032
# 17        Pasay  ...                 9        1755.56  1.167001
# 19     San Juan  ...                15        1613.33  2.127839
# 22     Marikina  ...                13        1553.85  1.675680
# 27       Taguig  ...                10        1700.00  1.313952
# 31       Makati  ...                14        1628.57  1.958280
# 34        Pasig  ...                12        1641.67  1.619160
# 38  Mandaluyong  ...                11        1654.55  1.449600
# 42     San Juan  ...                16        1575.00  2.240879
# 48  Quezon City  ...                14        1657.14  2.014799
#
#    Fraud_Flag_ZScore Fraud_Flag_IQR Order_Count  Fraud_Flag_Frequency  \
# 3                 OK             OK           6              FREQUENT
# 6                 OK             OK           6              FREQUENT
# 10                OK             OK           4              FREQUENT
# 13                OK             OK           6              FREQUENT
# 17                OK             OK           4              FREQUENT
# 19        SUSPICIOUS             OK           3                    OK
# 22                OK             OK           6              FREQUENT
# 27                OK             OK           4              FREQUENT
# 31                OK             OK           3                    OK
# 34                OK             OK           6              FREQUENT
# 38                OK             OK           4              FREQUENT
# 42        SUSPICIOUS             OK           3                    OK
# 48        SUSPICIOUS             OK           6              FREQUENT
#
#     Address_Mismatch  Order_Hour Fraud_Flag_Time
# 3           MISMATCH           2        ODD_HOUR
# 6           MISMATCH           3        ODD_HOUR
# 10          MISMATCH           1        ODD_HOUR
# 13          MISMATCH           2        ODD_HOUR
# 17          MISMATCH           3        ODD_HOUR
# 19          MISMATCH           4        ODD_HOUR
# 22          MISMATCH           1        ODD_HOUR
# 27          MISMATCH           2        ODD_HOUR
# 31          MISMATCH           3        ODD_HOUR
# 34          MISMATCH           1        ODD_HOUR
# 38          MISMATCH           2        ODD_HOUR
# 42          MISMATCH           4        ODD_HOUR
# 48          MISMATCH           1        ODD_HOUR
#
# [13 rows x 26 columns]

# %%
df.head(3)
# Out:
#     Name                   Email Financial Status Fulfillment Status   Total  \
# 0  #1001  maria.santos@gmail.com             paid          fulfilled  1250.0
# 1  #1002    john.reyes@yahoo.com             paid          fulfilled   850.0
# 2  #1003     anna.cruz@gmail.com             paid          fulfilled  2100.0
#
#    Subtotal  Shipping  Discount Amount           Created at Billing City  ...  \
# 0    1100.0     150.0              0.0  2026-01-02 10:23:00   Davao City  ...
# 1     750.0     100.0              0.0  2026-01-02 14:15:00    Cebu City  ...
# 2    1950.0     150.0              0.0  2026-01-03 09:45:00       Manila  ...
#
#   Shipping Country Payment Method Lineitem quantity Lineitem price   z_score  \
# 0               PH    Credit Card                 2          550.0 -0.556857
# 1               PH    Credit Card                 1          750.0 -0.602073
# 2               PH         PayPal                 3          650.0 -0.460773
#
#   Fraud_Flag_ZScore  Fraud_Flag_IQR  Order_Count  Fraud_Flag_Frequency  \
# 0                OK              OK            1                    OK
# 1                OK              OK            1                    OK
# 2                OK              OK            1                    OK
#
#   Address_Mismatch
# 0            MATCH
# 1            MATCH
# 2            MATCH
#
# [3 rows x 24 columns]

# %%
df['Discount_Pct'] = df['Discount Amount'] / df['Subtotal']

df['Fraud_Flag_Discount'] = np.where(
    df['Discount_Pct'] > 0.3,
    'HIGH_DISCOUNT','OK'
)

# %%
df.head(3)
# Out:
#     Name                   Email Financial Status Fulfillment Status   Total  \
# 0  #1001  maria.santos@gmail.com             paid          fulfilled  1250.0
# 1  #1002    john.reyes@yahoo.com             paid          fulfilled   850.0
# 2  #1003     anna.cruz@gmail.com             paid          fulfilled  2100.0
#
#    Subtotal  Shipping  Discount Amount          Created at Billing City  ...  \
# 0    1100.0     150.0              0.0 2026-01-02 10:23:00   Davao City  ...
# 1     750.0     100.0              0.0 2026-01-02 14:15:00    Cebu City  ...
# 2    1950.0     150.0              0.0 2026-01-03 09:45:00       Manila  ...
#
#     z_score Fraud_Flag_ZScore Fraud_Flag_IQR Order_Count Fraud_Flag_Frequency  \
# 0 -0.556857                OK             OK           1                   OK
# 1 -0.602073                OK             OK           1                   OK
# 2 -0.460773                OK             OK           1                   OK
#
#   Address_Mismatch  Order_Hour  Fraud_Flag_Time  Discount_Pct  \
# 0            MATCH          10               OK           0.0
# 1            MATCH          14               OK           0.0
# 2            MATCH           9               OK           0.0
#
#   Fraud_Flag_Discount
# 0                  OK
# 1                  OK
# 2                  OK
#
# [3 rows x 28 columns]

# %%
df.to_csv('shopify_orders_clean.csv', index=False)
