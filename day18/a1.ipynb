# %%
import torch

# %%
tensor1 = torch.tensor([1,2,3])
print('Tensor from List:',tensor1)

# %%
tensor2 = torch.zeros(2,3)
print("Tensor of zeroes:",tensor2)

# %%
tensor3 = torch.rand(3,2)
print('Random Tensor:',tensor3)

# %%
result_add = tensor1 + tensor2
print("Additional result:",result_add)

# %%
x = torch.tensor(2.0,requires_grad=True)
y = torch.tensor(3.0,requires_grad=True)

z = x**2 + y**3
print("Output tensor:",z)
z.backward()
print("Gradient of x:",x.grad)
print("Gradient of y:",y.grad)

# %%
number = []
number.append(10)
number.append(20)
print(number)

# %%
results = []
age = 17

if  age >= 18:
    results.append('Adult')
else:
    results.append("Minor")

print(results)

# %%
numbers = [1,2,3,4,5,6]
even_numbers = []

for n in numbers:
    if n % 2 == 0:
        even_numbers.append(n)

print(even_numbers)

# %%
grades = [85,72,90,60,40]
remarks = []

for grade in grades:
    if grade >= 75:
        remarks.append('Passed')
    elif grade >= 50:
        remarks.append('Remedial')
    else:
        remarks.append("Failed")

print(remarks)

# %%
x = torch.tensor(2.0,requires_grad=True)
y = torch.tensor(3.0,requires_grad=True)

z = x**2 + y**3
z.backward()

gradients = []

if x.grad > 2:
    gradients.append(('x',x.grad.item()))

if y.grad > 10:
    gradients.append(("y",y.grad.item()))

print(gradients)

# %%
scores = [95,67,82,45,73,59,88]
remark = []

for score in scores:
    if score > 90:
        remark.append('Excellent')
    elif score >= 75 and score < 90:
        remark.append("Good")
    elif score >= 60 and  score < 75:
        remark.append('Average')
    else:
        remark.append('Fail')

print(remark)

# %%
x = torch.tensor([-3.0,-1.0,0.0,2.0,4.0],requires_grad=True)

# %%
y = x**3
z = y.sum()




gradient_signs = []

for i in y:
    if i > 0:
        gradient_signs.append('Positive')
    elif i == 0:
        gradient_signs.append('Zero')
    else:
        gradient_signs.append('Negative')

print(f"Gradient {y} {z.backward()}")
print(f"Signs {gradient_signs}")

# %%
import torch

x = torch.tensor([-3.0, -1.0, 0.0, 2.0, 4.0], requires_grad=True)

y = x**3
z = y.sum()

z.backward()  # Compute gradients

gradient_signs = []

for grad in x.grad:  # Loop through gradients, not y
    if grad > 0:
        gradient_signs.append('Positive')
    elif grad == 0:
        gradient_signs.append('Zero')
    else:
        gradient_signs.append('Negative')

print("Gradients:", x.grad)
print("Signs:", gradient_signs)

# %%
x = torch.tensor([-2.0,-1.0,0.0,1.0,2.0], requires_grad=True )

# %%
y = x**4 + 2*x**2
z = y.sum()
z.backward()

# %%
x = torch.tensor([-2.0,-1.0,0.0,1.0,2.0], requires_grad=True )

y = x**4 + 2*x**2
z = y.sum()
z.backward()

categories = []

for grad in x.grad:
    val = abs(grad.item())
    if val < 5:
        categories.append('Low')
    elif val >= 5 and val < 20:   # ✅ correct range check
        categories.append('Medium')
    elif val >= 20:               # >= 20 is clearer
        categories.append('High')

print(x.grad)
print(categories)

# %%
import torch

# %%
x = torch.tensor([-3.0,-1.5,0.0,1.5,3.0],requires_grad=True)

y = torch.sigmoid(x) * torch.tanh(x)

z = y.sum()
z.backward()

catzz = []

for grad in x.grad:
    val = abs(grad.item())
    if val < 0.05:
        catzz.append("Weak")
    elif val  >= 0.05  and val < 0.15:
        catzz.append('Moderate')
    elif val >= 0.15:
        catzz.append("Strong")

print(x.grad)
print(catzz)

# %%
# !pip3 install imageio[ffmpeg]

# %%
ffmpeg -version

# %%
import torchaudio
from pydub import AudioSegment

# %%
torchaudio.set_audio_backend('sox_io')
waveform,sample_rate = torchaudio.load('well.wav')
print(waveform.shape)
print(sample_rate)
# Out:
# C:\Users\francis\AppData\Local\Temp\ipykernel_16484\2182396140.py:1: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   torchaudio.set_audio_backend('sox_io')
# e:\anaconda3\envs\torch4\lib\site-packages\torchaudio\_internal\module_utils.py:71: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   return func(*args, **kwargs)
# e:\anaconda3\envs\torch4\lib\site-packages\torchaudio\_backend\utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 torchaudio.set_audio_backend('sox_io')
# ----> 2 waveform,sample_rate = torchaudio.load('well.wav')
#       3 print(waveform.shape)
#       4 print(sample_rate)
#
# File e:\anaconda3\envs\torch4\lib\site-packages\torchaudio\_backend\utils.py:221, in get_load_func.<locals>.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     129 """Load audio data from source.
#     130
#     131 .. warning::
#    (...)
#     211         `[channel, time]` else `[time, channel]`.
#     212 """
#     213 warnings.warn(
#     214     "In 2.9, this function's implementation will be changed to use "
#     215     "torchaudio.load_with_torchcodec` under the hood. Some "
#    (...)
#     219     "https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder."
#     220 )
# --> 221 backend = dispatcher(uri, format, backend)
#     222 return backend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#
# File e:\anaconda3\envs\torch4\lib\site-packages\torchaudio\_backend\utils.py:117, in get_load_func.<locals>.dispatcher(uri, format, backend_name)
#     115     if backend.can_decode(uri, format):
#     116         return backend
# --> 117 raise RuntimeError(f"Couldn't find appropriate backend to handle uri {uri} and format {format}.")
#
# RuntimeError: Couldn't find appropriate backend to handle uri well.wav and format None.
