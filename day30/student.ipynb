# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('student_performance.csv')

# %%
average_student_age = df['Age'].mean()
print(f'Average student age: {average_student_age}')
# Out:
# Average student age: 17.5

# %%
attendance_check = df.groupby('Name')['Attendance'].idxmax()
print(attendance_check)
# Out:
# Name
# Alice       0
# Bob         1
# Charlie     2
# David       3
# Eve         4
# Frank       5
# Grace       6
# Hannah      7
# Ivy         8
# Jack        9
# Kevin      10
# Liam       11
# Mia        12
# Noah       13
# Olivia     14
# Peter      15
# Quinn      16
# Ryan       17
# Sophia     18
# Tom        19
# Name: Attendance, dtype: int64
# C:\Users\francis\AppData\Local\Temp\ipykernel_25540\1609333114.py:1: FutureWarning: The 'axis' keyword in SeriesGroupBy.idxmax is deprecated and will be removed in a future version. Call without passing 'axis' instead.
#   attendance_check = df.groupby('Name')['Attendance'].idxmax(0)

# %%
attendance_sum = df.groupby('Name')['Attendance'].sum()


top_name = attendance_sum.idxmax()
top_value = attendance_sum.max()

print(top_name,top_value)
# Out:
# Eve 98

# %%
attendance_sum = df.groupby('Name')['Attendance'].sum()

if not attendance_sum.empty:
    print(attendance_sum.idxmax(),attendance_sum.max())
else:
    print('No Attendance data')
# Out:
# Eve 98

# %%
study_correlation = df['StudyHours'].corr(df['MathScore'])
