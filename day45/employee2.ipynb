# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
employee_data = pd.read_csv('employees.csv')

# %%
employee_data
# Out:
#     employee_id   first_name  last_name   department                job_title  \
# 0             1         John      Smith  Engineering        Software Engineer
# 1             2        Sarah    Johnson    Marketing        Marketing Manager
# 2             3      Michael   Williams  Engineering         Senior Developer
# 3             4        Emily      Brown           HR            HR Specialist
# 4             5        David      Jones        Sales     Sales Representative
# 5             6      Jessica     Garcia  Engineering           Data Scientist
# 6             7  Christopher   Martinez      Finance        Financial Analyst
# 7             8       Amanda  Rodriguez    Marketing       Content Specialist
# 8             9        James     Wilson  Engineering          DevOps Engineer
# 9            10       Ashley   Anderson        Sales            Sales Manager
# 10           11      Matthew     Thomas      Finance        Senior Accountant
# ...
